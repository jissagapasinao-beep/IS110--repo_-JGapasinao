# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x = 60

if x > 50:
    print('Above 50')
elif x > 20:
    print('Above 20')
elif x > 10:
    print('Above 10')
elif x > 0:
    print('Above 0')
else:
    print('Something else')

# Test with another value
x = 15

if x > 50:
    print('Above 50')
elif x > 20:
    print('Above 20')
elif x > 10:
    print('Above 10')
elif x > 0:
    print('Above 0')
else:
    print('Something else')

# Test with a value below 0
x = -5

if x > 50:
    print('Above 50')
elif x > 20:
    print('Above 20')
elif x > 10:
    print('Above 10')
elif x > 0:
    print('Above 0')
else:
    print('Something else')
# Out:
# Above 50
# Above 10
# Something else

# %%
hours_str = input('Enter Hours: ')
rate_str = input('Enter Rate: ')

try:
    hours = float(hours_str)
    rate = float(rate_str)
except:
    print('Error: Please enter numeric input for hours and rate')
    quit()

if hours > 40:
    # Calculate regular pay for the first 40 hours
    regular_pay = 40 * rate
    # Calculate overtime hours
    overtime_hours = hours - 40
    # Calculate overtime pay
    overtime_pay = overtime_hours * (rate * 1.5)
    # Total pay is regular pay plus overtime pay
    total_pay = regular_pay + overtime_pay
else:
    # If no overtime, total pay is simply hours multiplied by rate
    total_pay = hours * rate

print('Pay:', total_pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %%
score_str = input('Enter score (between 0 and 100): ')

try:
    score = float(score_str)
except:
    print('Bad score')
    quit()

if not (0 <= score <= 100):
    print('Bad score')
elif 97 <= score <= 100:
    print('1.0')
elif 93 <= score < 97:
    print('1.25')
elif 89 <= score < 93:
    print('1.5')
elif 85 <= score < 89:
    print('1.75')
elif 81 <= score < 85:
    print('2.0')
elif 77 <= score < 81:
    print('2.25')
elif 74 <= score < 77:
    print('2.5')
elif 0 <= score < 74:
    print('3.0')
else:
    print('Bad score') # This case should ideally not be reached if previous conditions are exhaustive and mutually exclusive
# Out:
# Enter score (between 0 and 100): 98
# 1.0
